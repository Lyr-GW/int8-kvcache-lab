# %% [markdown]
# # Dynamic INT8 KV Cache Lab\nSelect a GPU runtime with at least 24 GiB VRAM before continuing. This notebook validates a correctness-first dynamic path; it does not claim a speedup.

# %%
# Set this to the public Git URL containing int8-kvcache-lab.\nREPO_URL = 'https://github.com/<OWNER>/<REPOSITORY>.git'\nPROJECT_REF = 'main'\n!git clone --depth 1 --branch {PROJECT_REF} {REPO_URL} /content/project\n%cd /content/project/int8-kvcache-lab\n!bash scripts/bootstrap_colab.sh

# %%
# Optional: download generated JSON reports.\n!ls -lah artifacts
